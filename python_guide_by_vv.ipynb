# %% [markdown]
# <a href="https://colab.research.google.com/github/vviedienieiev/Learning/blob/main/python_guide_by_vv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center"> Python гайд для новичков </h1>
# <p align="right">Автор: Владимир Веденеев </p>
# <p align="right">Создано: 31-07-2021 </p>

# %% [markdown]
# **<h2>Оглавление</h2>**
# <ol>
# <li> Предисловие; </li>
# <li> Пререквизиты; </li>
# <li> Плюсы и минусы Python; </li>
# <li> Зарплаты Python программистов: </li>
#     <ol>
#     <li> 4.1 Общие зарплаты Python программистов; </li>
#     <li> 4.2 Зарплаты Python программистов по грейдам; </li>
#     </ol>
# <li> Роадмап по скилам; </li>
# <li> Ресурсы для учебы; </li>
# <li> Как правильно решать задачи в программировании; </li>
# <li> Источники практических знаний;</li>
# <li> Монетизация Python навыков;</li>
# <li> Какой компьютер/ноутбук нужен для программирования; </li>
# <ol>

# %% [markdown]
# **<h2>1. Предисловие</h2>**
#
# Гайд создан для людей, которые еще ни разу не сталкивались с программированием, но очень хотят ему научиться. Я надеюсь, что после прочтения этого гайда у многих людей отпадут вопросы. Цель этого гайда не научить тебя программировать на Python, но помочь тебе информацией, которая позволит учить Python максимально эффективно.
#
# ---

# %% [markdown]
# **<h2>2. Пререквизиты</h2>**
#
# Этот гайд не имеет каких-то особых требований к знаниям и навыкам. Если ты знаешь как включается компьютер, как работать с браузером и знаешь как загуглить что-то, то этот гайд тебе подойдет.
#
# ---

# %% [markdown]
# **<h2>3. Плюсы и минусы Python</h2>**
#
# Итак, ты дочитал уже до этого пункта. Молодец!
# Теперь, прежде чем ты окончательно решишь связать свою жизнь с программированием и языком программирования (<b>ЯП</b>) Python в частности, пожалуйста, посмотри на его "плюсы" и "минусы". Это позволит понять, подходит ли он под твои цели и нужно ли на него тратить свое время.
#
# Преимущества Python:
#
# 1. Простой синтаксис, который похож на английский язык;
# 2. Динамическая типизация (это как плюс так и минус, но я лично считаю плюсом);
# 3. Большое мировое сообщество и огромное количество библиотек. Шансы, что у вас возникнет вопрос, который еще не решен - минимальны, особенно в начале вашего пути в программировании.
# 4. Отлично подходит для прототипирования. Можно за 5-10 минут сделать прототип, который в других ЯП займет несколько часов.
# 5. Широко используется в веб-деве, создании ботов и парсеров и в data science.
#
# Недостатки Python:
# 1. Медленее, чем некоторые другие ЯП;
# 2. Проблемы с тредингом;
# 3. Не нативный для мобильной среды, что затрудняет разработку мобильных приложений;
# 4. Требует значительных объемов памяти.
#
# Подводя итоги, Python хорошо подходит начинающим программистам из-за своего легкого синтаксиса. Кроме того, на нём удобно писать сравнительно небольшие программы и скрипты, которые подойдут для персонального использования или малого/среднего бизнеса. Если ты мечтаешь построить программу, которой будет пользоваться больше 100 тысяч людей каждый день, то лучше начни учить другой ЯП, который больше подходит к таким задачам.
#
# ---

# %% [markdown]
# **<h2>4. Зарплаты Python программистов</h2>**
# <h3>4.1 Общие зарплаты Python программистов</h3>
#
# Автор из Украины, поэтому зарплаты были взяты с [Djinni](https://djinni.co/analytics/salaries) и актуальны на дату 31-07-2021. Если ты читаешь эту статью позже или ты не из Украины, то ЗП могут отличаться.

# %% [markdown]
# ![Зарплаты Python программистов](data:image/png;base64,...)

# %% [markdown]
# Посмотрев на график сверху, ты можешь восхититься зарплатами в 5000 USD и выше. Прежде чем ты начнешь учить Python в надежде быстро зарабатывать такие деньги, я обязан тебя предупредить, что такие зарплаты получают очень опытные программисты. Для этого им требуется несколько лет опыта работы (на момент написании статьи около 4х лет работы, без учета времени, которое они потратили на изучение языка). Поэтому, если ты хочешь по-быстрому начать зарабатывать тысячи долларов в месяц, то забудь. Программирование будет требовать от тебя значительных инвестици времени и усилий, прежде чем ты начнешь зарабатывать хотя бы 800 USD в месяц.

# %% [markdown]
# <h3>4.2 Зарплаты Python программистов по грейдам</h3>
#
# Я думаю ни для кого не секрет, что все люди имеют разный опыт работы, разные навыки и знания. Поэтому, нет ничего удивительного, что программисты также отличаются по этим показателям. Чтобы иметь представление о том, насколько крут программист, то в мире айти приняты определенные грейды.
#
# Если использовать определение данное википедией, то
# > Грейдинг (англ. grading) — группировка должностей по определённым основаниям (определение «веса», классификация) с целью построения системы мотивации. Суть грейдинга — в сопоставлении внутренней значимости должностей для организации (внутренняя ценность) с ценностью этой работы на рынке (внешняя ценность).
#
# Если же использовать человеческий язык, то грейд это уровень человека в какой-то области, который определяет в среднем его зарплату.
#
# В программировании различают такие грейды:
#
# **Junior -> Middle -> Senior -> Lead -> Architect -> Chief Technology Officer (CTO)**
#
# При этом, джуниор является начальной ступенью.
# Сразу сделаю оговорку, что в разных компаниях иерархия и грейдинг могут быть другими, но в целом ты можешь использовать эту структуру как компас для продвижения по карьерной лестнице.
#
# В таблице ниже я приведу средний необходимый опыт работы в годах и ЗП для джуна, мидла и синьора, так для них опыт работы и ЗП не слишком отличаются по рынку (тем не менее всегда можно встретить синьора с ЗП в 2000 USD или мидла с ЗП в 4000. Это рынок и умение договариваться будет иметь значительное влияние на твою ЗП):
#
# |Грейд|Опыт, года|Зарплата, USD|
# |-----|----|--------|
# |Junior|0-2|400-800|
# |Middle|1-4|1200-3500|
# |Senior|3-7|2500-6000|
#
# Данные в таблице являются субъективными и взяты на основании разговоров с друзьями, знакомыми, коллегами и людьми из разных чатов и тд.
#
# В любом случае, данные в таблицы дают примерное представление, что ожидать от вашего карьерного роста. И я советую перепроверить их на момент прочтения гайда, так как все может поменяться :)
#
# ---

# %% [markdown]
# **<h2>5. Роадмап по скилам</h2>**
#
# Итак, по моему субьективному мнению у 100% новичков в программировании (не только Python, но и любой другой ЯП) возникает 2 основных вопроса:
# *   Что учить?
# *   Где учить?
#
# Данная секция позволит тебе получить ответ на вопрос "что учить?".
#
# Первое и что самое главное вам надо выучить - это английский язык. Из всей информации, которую вы будете искать и находить 99% будут именно на нем. Поэтому, постарайтесь довести свой уровень английского, хотя бы до B1, а лучше даже до B2. Кроме того, английский нужен для получения работы в большинстве компаний.
#
# Идём дальше. Важным этапом является изучение "Core Python" топиков, которые представлены на картинке ниже.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Самое интересное заключается в изучении фреймворков.
# На момент написания статьи Python чаще всего используется в 3х направлениях:
#
#
# 1.   Web-development
# 2.   Data Science
# 3.   Написание ботов, парсеры и тд.
#
# Для каждого из этих направлений есть свои фреймворки, которые необходимо знать и без которых шансов трудоустроиться у тебя почти нет.
#
# Для web-development популярными фрейморками являются: Django, Flask (я рекоммендую начинать с него), Aiohttp, FastApi
#
# Для Data Science популярными фреймворками являются: Pandas, Numpy, Sklearn, Tensorflow
#
# Написанае ботов и парсеров является третьим большим направлением, в котором используется Python. Для парсеров существуют такие фреймоврки, как request, BeautifulSoup, Selenium, Scrapy. Эти фрейморки довольно просты для изучения и являются отправной точкой для изучения парсинга. В тоже время, для написания ботов не существуюе общепринятых фреймворков, так как зачастую у каждого продукта, для которого пишется бот, есть своя документация, под которую тебе необходимо будет подстроиться. Например для телеграмма можно использовать библиотеки aiogram, telethon или pyrogram. Для twilio есть своя библиотека twilio.rest. И так почти для любого продукта.
#
# Более детальный роадмап доступен по ссылке [Python roadmap](https://github.com/vviedienieiev/Learning/blob/main/Roadmaps/Syllabus%2Bfor%2B100%2BDays%2Bof%2BPython.pdf)
#
# Кроме самого Python во время учёбы тебе, скорее всего, придётся познакомиться с такими ЯП, как html,css,js,sql и получить опыт работы с такими инструментами как git, database, BI tools и тд. Не пугайся - это нормально и на это тоже придётся потратить свое время, чтоб уметь работать с ними хотя бы на самом базовом уровне.
#
# Итого, выучив все Core Python темы и имея базовые знания (конечно с минимальным практическим опытом) в каком-то из трех направления, у тебя появятся шансы получить позицию джуниора в компании.
#
# ---

# %% [markdown]
# **<h2>6. Ресурсы для учебы</h2>**
#
# <h3>Английский</h3>
# <h4>Книги:</h4>
# <h4>Курсы:</h4>
#
# <ol>
# <li><a href="https://www.youtube.com/watch?v=Hp9wUEDasY4">АНГЛИЙСКИЙ ЯЗЫК ПЛЕЙЛИСТАМ</a></li>
# </ol>
#
# <h3>Core Python</h3>
# <h4>Книги:</h4>
# <h4>Курсы:</h4>
#
# <ol>
# <li><a href="https://online-learning.harvard.edu/course/cs50-introduction-computer-science">CS50: Introduction to Computer Science</a></li>
# <li><a href="https://www.youtube.com/watch?v=KdZ4HF1SrFs">Тимофей Хирьянов</a></li>
# <li><a href="https://www.udemy.com/course/100-days-of-code/">Сто дневной буткамп </a> (его стоит покупать по скидке, за 15 долларов максимум)</li>
# </ol>
#
#
# <h3>Python Frameworks</h3>
# <h4>Книги:</h4>
# <ol>
# <li><a href="https://github.com/vviedienieiev/Learning/blob/ebada3603a6839ec83fb76123a3961173368b72c/Books/Two%20Scoops%20of%20Django%203.x%20Best%20Practices%20for%20the%20Django%20Web%20Framework%20by%20Daniel%20Feldroy,%20Audrey%20Feldroy.pdf">Two Scoops of Django 3.x Best Practices for the Django Web Framework by Daniel Feldroy, Audrey Feldroy</a> - Очень хорошая книга, чтобы начать учить фреймворк Django</li>
# </ol>
# <h4>Курсы:</h4>
#
#
# <h3>Другие полезные источники</h3>
# <ol>
# <li><b><a href="https://www.lifehack.org/articles/technology/20-tips-use-google-search-efficiently.html">How to Google</a></b> - я понимаю, что ты думаешь, что умеешь гуглить. Но, пожалуйста, посмотри эту статью, чтобы научиться делать правильные гугл запросы и сократить время поиска нужной инфы.</li>
# <li><a href="https://www.youtube.com/user/sentdex">Sentdex</a> - один из лучших ютуб каналов по программированию используя Python. Много идей и классные реализации.</li>
# <li><a href="https://www.coursera.org/learn/machine-learning">Machine Learning - Standford </a> - Просто библия для начинающего дата саентиста.</li>
# <li><a href="https://www.coursera.org/specializations/deep-learning">Deep Learning - deeplearning.ai </a> - Продолжение курса выше. Этот курс больше сфокусирован на нейронных сетях и глубоком обучении.</li>
# <li><a href="https://www.datacamp.com"> Datacamp </a> - Крутая платформа с кучей курсов по Python и не только. Если будет выбор между курсами за 100500 долларов и датакампом, то лучше купи годовую подписку на датакамп.</li>
# <li><a href="https://www.sql-ex.ru/"> Sql-ex </a> - Подборка задач для тренировки SQL</li>
# <li><a href="https://www.codewars.com/"> Codewars </a> - сайт с задачами по Python. Можно спокойно решать задачи до 4 kyu. Более сложные задачи нет смысла решать, так как они уже требуют больше знать алгоритмы, чем программирование.</li>
# <li><a href="https://www.w3schools.com/"> W3School </a> - тут есть много теоретической инфы по html и не только.</li>
# </ol>

# %% [markdown]
# **<h2>7. Как правильно решать задачи в программировании</h2>**
#
# Тебе, как начинающему программисту, конечно же хочется побыстрее всё выучить и начать зарабатывать деньги. Я считаю, что для того, чтобы перейти в категорию джуна, то нужно потратить около 1000 часов на учёбу. Проблема заключается в том, что эти 1000 часов можно потратить с разной эффективностью, что скажется на твоем опыте и знаниях после окончания учебы. Тут стоит уточнить, что речь идёт об учебе, чтобы стать джуном, так как в программировании учёба не заканчивается никогда. Все время придётся учить новые фреймворки, ЯП и тд, чтобы быть конкурентноспособным.
# Так вот, в интернете есть множество статей, как правильно решать задачи в программировании. Например, ты можешь прочитать эту статью [10 Steps to Solving a Programming Problem](https://codeburst.io/10-steps-to-solving-a-programming-problem-8a32d1e96d74).
# Лично я считаю, что любой начинающий программист должен стараться по-максимуму делать задания самостоятельно (использовать либы не запрещается, а вот искать сразу готовое решение - не лучший выбор для новичка). Поэтому, я советую придерживаться следующего алгоритма решения задач во время учебы:
# 1. Понять суть задачи. Тут надо прочитать несколько раз условие, чтобы не пропустить нюансы и быть увереным, что задача понята правильно.
# 2. Постараться придумать алгоритм решения задачи. Если алгоритм тяжело придумать в уме, то лучше его записывать.
# 3. Если ты потратил больше часа времени на алгоритм, но так и не придумал решение, то можно загуглить именно алгоритм решения такой задачи (не надо гуглить готовое решение).
# 4. Написать код, который реализует придуманный/найденный алгоритм. Если написать код тяжело, то сначала напиши псевдокод, а потом перепиши его в нормальный код (тут можно некоторые части гуглить)
# 5. Если задача слишком сложная и не получается написать ее решение, то можно загуглить готовое решение, но обязательно нужно его разобрать. Также, лучше остановись на задачах этого уровня сложности и решай их, пока не поймешь, что они легко даются тебе.
# 6. Поздравляю! Ты написал или нашел готовый код решения задачи. Посмотри на него и подумай, что можно улучшить. Проверь, что он действительно правильно работает и возвращает правильные ответы для разных типов входных данных.
# 7. Почитай подробнее про вещи, с которыми у тебя возникли проблемы в коде.
#
# PS. Очень часто начинающие программисты сразу бегут с вопросами к более опытным программистам вместо того, чтобы сесть и подумать самим. Я считаю, что это абсолютно неверная тактика, так как умение думать и находить решения  самостоятельно (может быть даже с помощью Гугла) является **САМЫМ НЕОБХОДИМЫМ НАВЫКОМ** для любого программиста. Поэтому, старайся просить помощи у других людей только после того, как ты сам подумал, погуглил, попытался написать код, подумал, что не так с кодом, и попробовал исправить. Если ты всё это сделал и всё равно не получается, тогда проси помощи.
#
# ---

# %% [markdown]
# **<h2>8. Источники практических знаний?</h2>**
#
# Теория - это конечно круто, но практика - круче. Обучаясь программированию нельзя забывать про цель учёбы, а именно, в большинстве случаев, желание найти работу. Ты должен понимать, что большинству работодателей не нужны неопытные программисты, которые не могут написать хотя бы самый простой, рабочий код. Поэтому, твоя задача за время учёбы приобрести максимально релевантный практический опыт.
#
# Не имея практического опыта, шансы попасть на собеседования у тебя меньше 20% (вряд ли ты сможешь пройти больше чем 1 из 5 скрининг интервью). Наличие же хотя бы минимального количества пет-проектов, которые залиты на github и правильно оформлены (PEP8 в помощь),  сразу же повышает твои шансы заинтересовать компании.
#
# Я лично считаю, что для начинающего программиста лучшими местами и вещами для составления портфолио являются:
# 1. Школы и стажировки при компаниях;
# 2. Хакатоны и олимпиады;
# 3. Пет-проекты;
# 4. Небольшие фриланс проекты.
#
# Ниже список сайтов, который ты можешь использовать в процессе создания своего портфолио:
#
# 1. [Epam university program;](training.epam.ua)
# 2. [SoftServe;](https://career.softserveinc.com/uk-ua/learning-and-certification)
# 3. [GlobalLogic BaseCamp](https://www.globallogic.com/ua/gl-basecamp/)
# 4. [Обучение и стажировки в IT в 2020 году
# ](https://vc.ru/u/517977-aleksey-anisimov/129668-obuchenie-i-stazhirovki-v-it-v-2020-godu) - я не разбираюсь в российском IT-рынке, поэтому могу только порекоммендовать эту статью для дальнейшего поиска стажировок.
# 5. [Kaggle](https://www.kaggle.com/)
# 6. [Hackerearth](https://www.hackerearth.com/ru/challenges/)
# 7. [13 Project Ideas for Intermediate Python Developers
# ](https://realpython.com/intermediate-python-project-ideas/)
# 8. [100 Programming Projects Just for You
# ](https://dev.to/anthonygedeon/100-programming-projects-just-for-you-56b6)
# 9. [42 Exciting Python Project Ideas & Topics for Beginners
# ](https://www.upgrad.com/blog/python-projects-ideas-topics-beginners/)
#
# ---

# %% [markdown]
# **<h2>9. Монетизация Python навыков?</h2>**
#
# Ух, ты уже на этапе, когда пора зарабатывать первые деньги. Твои теоретические знания и практический опыт позволяют выбрать один из трех вариантов как монетизировать твои навыки, а именно:
# 1. Работа на компанию;
# 2. Работа на фрилансе;
# 3. Создания своего собственного проекта.
#
# Посмотрев этот список, у тебя может возникнуть вопрос, подходит ли Python для для этих работ? Ответ однозначен - да. Сейчас открыто огромное кол-во вакансий и заданий для людей, которые обладают навыками в программировании на Python.
#
# Я не буду расписывать плюсы и минусы выбора любого из направлений деятельности, так как для этого есть гугл. Я могу лишь предложить список материалов и источников, которые помогут на твоем пути.
#
# Итак, если ты готов работать на компанию, то тебе может пригодиться следующее:
#
# *   [I can choose](https://icanchoose.ru/resume/) - составление правильного резюме - это твой первый шаг к получению работы. Данный сервис поможет тебе быстро и бесплатно сделать красивое резюме со всей необходимой информацией
# *   [GitHub](https://github.com/) - Почти все IT-компании используют гитхаб. Ты можешь хранить здесь свои пет-проекты. Правильно оформленный и регулярно обновляемый гитхаб является ключом к успешному интервью.
# *   [Djinni](https://djinni.co/) - Как по мне, один из лучших аггрегаторов вакансий для поиска работы в Украине.
# *   [HeadHunter](https://hh.ru/) - Для российского рынка мне посоветовали этот сайт. Я не могу сказать насколько он подходит для поиска вакансий в IT, но все же решил добавить.
# * [DOU](https://dou.ua/) - Просто идеальный сайт для айтишника в Украине. Тут можно найти не только последние новости IT рынка, но и почитать комментарии про компании (что очень полезно при выборе компаний).
#
# Если же ты хочешь быть независимым от постоянного работодателя и тебе нравится проектная работы, тогда твой путь лежит во фриланс. Тебе могут помочь такие исчтоники:
#
# * [Upwork](https://www.upwork.com/) - Самая большая в мире фриланс биржа. Сразу предупреждаю, что на ней очень важна репутации, поэтому придется потратить много времени (до года, а может и больше) создавая свое портфолио из выполненных проектов и свою репутацию.
# * [20+ ресурсов, чтобы начать фрилансить](https://habr.com/ru/company/icanchoose/blog/347806/) - Список бирж, на которых можно фрилансить. Большинство из них русскоязычные.
# * [Советы начинающим фрилансерам](https://habr.com/ru/post/143136/) - Из названия понятно, что это список советов. И да, ты можешь забить на эту статью и сразу окунуться в мир фриланса. Но я все же порекоммендую тебе потратить 5 минут на прочтение этой статьи и еще 5 минут на то, чтобы осознать написанное. Это позволит тебе сэкономить много нервов и, возможно, денег в будующем.
#
# Если у тебя есть гениальная идея и ты решил пилить свой проект, то у меня для тебя всего несколько советов:
# 1. Перед началом проекта проведи исследования и построй хотя бы минимальную модель твоего проекта. Будет неприятно осознать через полгода, что идея не имела никаких шансов на жизнь.
# 2. Старайся сделать MVP(Minimum Value Product) - минимальную рабочую версию продукта. Если у тебя большой проект, то ты все равно не сможешь его сделать идеальным сразу. В таком случае, MVP покажет стоит работать дальше или нет.
# 3. Спрашивай, читай, анализируй - советы опытных людей помогут избежать многих проблем.
#
#
#
#
#
#
# ---

# %% [markdown]
# **<h2>10. Какой компьютер/ноутбук нужен для программирования</h2>**
#
# Если ты задался этим вопросом, то всё зависит от того, какую задачу ты хочешь решить. Если ты не собираешься решать дата саенс задачи и тебе не нужно создавать графику для игр, тогда подойдет любой ноутбук/компьютер до 1000 долларов. Если, ты всё же собираешься заниматься ДС, то на первое время тебе также подойдет ноутбук до 1000 долларов, так как большую часть задач ты можешь выполнять с помощью [Google Colaboratory](https://colab.research.google.com/).
# Позже, сможешь сменить его на ноутбук с большим кол-вом памяти и очень хорошей видеокартой.
#
# Выбирая между операционной системой, бери ту, которая тебе удобнее. Для дата саенс на момент написания статьи макбуки все же немного лучше.
#
# ---

# %% [markdown]
# Если у тебя есть идеи, комментарии, предложения или вопросы, то ты можешь связаться со мной такими способами:
# 1. [LinkedIn](https://www.linkedin.com/in/viedienieiev/)
# 2. [Telegram](https://t.me/v_vied)
