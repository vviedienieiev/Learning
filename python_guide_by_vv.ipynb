# %% [markdown]
# <a href="https://colab.research.google.com/github/vviedienieiev/Learning/blob/main/python_guide_by_vv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center"> Python гайд для новичков </h1>
# <p align="right">Автор: Владимир Веденеев </p>
# <p align="right">Создано: 31-07-2021 </p>

# %% [markdown]
# **<h2>Оглавление</h2>**
# <ol>
# <li> Предисловие; </li>
# <li> Пререквизиты; </li>
# <li> Плюсы и минусы Python; </li>
# <li> Зарплаты Python программистов. </li>
#     <ol>
#     <li> 4.1 Общие зарплаты Python программистов </li>
#     <li> 4.2 Зарплаты Python программистов по грейдам </li>
#     </ol>
# <ol>

# %% [markdown]
# **<h2>1. Предисловие</h2>**
# <p>Гайд создан для людей, которые еще ни разу не сталкивались с программирование, но очень хотят ему научиться. Я надеюсь, что после прочтения этого гайда у многих людей отпадут вопросы.</p>
#
# ---

# %% [markdown]
# **<h2>2. Пререквизиты</h2>**
# Этот гайд не имеет каких-то особых требований к знаниям и навыкам. Если ты знаешь как включается компьютер, как работать с браузером и знаешь как загуглить что-то, то этот гайд тебе подойдет.
#
# ---

# %% [markdown]
# **<h2>3. Плюсы и минусы Python</h2> **
# Итак, ты дочитал уже до этого пункта. Молодец!
# Теперь, прежде чем ты окончательно решишь связать свою жизнь с программированием и яхыком программирования (<b>ЯП</b>) Python в частности, пожалуйста, посмотри на его "+" и "-". Это позволит понять, подходит ли он под твои цели и нужно ли на него тратить свое время.
#
# Преимущества Python:
#
# 1. Простой синтаксис, который похож на английский язык;
# 2. Динамическая типизация (это как плюс так и минус, но я лично считаю плюсом);
# 3. Большое мировое сообщество и огромное количество библиотек. Шансы, что у вас возникнет вопрос, который еще не решен - минимальны, особенно в начале вашего пути в программировании.
# 4. Отлично подходит для прототипирования. Можно за 5-10 минут сделать прототип, который в других ЯП займет несколько часов.
# 5. Широко используется в веб-деве, создании ботов и парсеров и в data science.
#
# Недостатки Python:
# 1. Медленее, чем некоторые другие ЯП;
# 2. Проблемы с тредингом;
# 3. Не нативный для мобильной среды, что затрудняет разработку мобильных приложений;
# 4. Требует значительных объемов памяти.
#
# Подводя итоги, Python хорошо подходит начинающим программистам из-за своего легкого синтаксиса. Кроме того, на нём удобно писать сравнительно небольшие программы и скрипты, которые подойдут для персонального использования или малого/среднего бизнеса. Если ты мечтаешь построить программу, которой будет пользоваться больше 100 тысяч людей каждый день, то лучше начни учить другой ЯП, который больше подходит к таким задачам.
#
# ---

# %% [markdown]
# **<h2>4. Зарплаты Python программистов</h2>**
# <h3>4.1 Общие зарплаты Python программистов</h3>
#
# Автор из Украины, поэтому зарплаты были взяты с [Djinni](https://djinni.co/analytics/salaries) и актуальны на дату 31-07-2021. Если ты читаешь эту статью позжу или ты не из Украины, то ЗП могут отличаться.
# ![Зарплаты Python программистов](data:image/png;base64,...)
#
# Прежде, чем ты в восхищении от зарплат в 5000 USD и выше решишь учить Python, хочу уточнить, что ЗП в 5000 USD получают очень опытные программисты и для этого им требуется несколько лет опыта (на момент написании стать около 4х лет работы, без учета времени, который они потратили на изучение языка). Поэтому, если ты хочешь по-быстрому начать зарабатывать тысячи долларов в месяц, то забудь. Программирование будет требовать от тебя значительных инвестици времени и усилий, прежде чем ты начнешь зарабатывать хотя бы 800 USD в месяц.

# %% [markdown]
# <h3>4.2 Зарплаты Python программистов по грейдам</h3>
# Я думаю ни для кого не секрет, что все люди имеют разный опыт работы, разные навыки и знания. Поэтому, нет ничего удивительного, что программисты также отличаются по этим показателям. Чтобы иметь представление о том, насколько крут программист, то в мире айти приняты определенные грейды.
#
# Если использовать определение данное википедией, то
# > Грейдинг (англ. grading) — группировка должностей по определённым основаниям (определение «веса», классификация) с целью построения системы мотивации. Суть грейдинга — в сопоставлении внутренней значимости должностей для организации (внутренняя ценность) с ценностью этой работы на рынке (внешняя ценность).
#
# Если же использовать человеческий язык, то грейд это уровень человека в какой-то области, который определяет в среднем его зарплату.
#
# В программировании разлиают такие грейды:
#
# **Junior -> Middle -> Senior -> Lead -> Architect -> Chief Technology Officer (CTO)**
#
# При этом, джуниор является начальной ступенью.
# Сразу сделаю оговорку, что в разных компаниях иерархия и грейдинг может быть другая, но в целом ты можешь использовать эту структуру как компас для продвижения по карьерной лестнице.
#
# В таблице ниже я приведу средний необходимый опыт работы в годах и ЗП для джуна, мидла и синьора, так для них опыт работы и ЗП не слишком отличаются по рынку (тем не менее всегда можно встретить синьора с ЗП в 2000 USD или мидла с ЗП в 4000. Это рынок и умение договаривать будет иметь значительное влияние на твою ЗП):
#
# |Грейд|Опыт, года|Зарплата, USD|
# |-----|----|--------|
# |Junior|0-2|400-800|
# |Middle|1-4|1200-3500|
# |Senior|3-7|2500-6000|
#
# Данные в таблице являются субьективными и взяты на основании разговоров с друзьями, знакомыми, коллегами и людьми из разных чатов и тд.
#
# В любом случае, данные в таблицы дают примерное представление, что ожидать от вашего карьерного роста. И я советую перепроверить их на момент прочтения гайда, так как все может поменяться :)
